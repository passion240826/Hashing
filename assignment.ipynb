# %% [markdown]
# # 1번
#
# 1. 개방 주소방법(Open Addressing)
# 2. 체이닝(Chaining)
#
# | 구분     | 개방 주소법(Open Addressing) | 체이닝(Chaining)       |
# | ------ | ----------------------- | ------------------- |
# | 장점     | 메모리 추가 사용 적음            | 충돌 많아도 처리 쉬움        |
# | 장점     | 캐시 효율 좋음                | 삭제가 쉬움              |
# | 단점     | 충돌 많아지면 탐색 길어짐          | 연결 리스트 추가 메모리 필요    |
# | 단점     | 삭제 처리 복잡                | 캐시 효율 낮음            |

# %% [markdown]
# # 2번
#
# ### 2-1
#
# ### 2-2
